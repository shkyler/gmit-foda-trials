# %% [markdown]
# # Monty Hall Problem Simulator

# %% [markdown]
# ![Monty Hall](IMG/montydoor.png)

# %% [markdown]
# This notebook runs a python script that has been written to simulate the "Monty Hall Problem" (Wikipedia - https://en.wikipedia.org/wiki/Monty_Hall_problem). The script simulates the game 10,000 times each for each situation (either the contestant stays or switches). It then plots the results for the number of wins and losses in each case. Each time the program is run and new set of data is simulated.

# %%
#Tell matplotlib to run its graphics "inline"
# %matplotlib inline
#Run the Monty Hall Simulator
# %run montysim.py

# %% [markdown]
# It can be seen from the simulations that switching is the better way to go - it doubles your chances of winning the car. Provided, that is, it was the car you were after! (Comic from xkcd - https://www.xkcd.com/1282/)

# %% [markdown]
# ![Win a Goat](IMG/montyxkcd.png)
